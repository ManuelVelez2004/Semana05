# %% [markdown]
# Temas
# 1. Colecciones de datos
# 2. Estructuras decisivas y Estrcuturas repetitivas
# 3. Clases y Objetos
# 4. Funciones

# %% [markdown]
# 1.COLECIONES DE DATOS

# %%
#1.1 Listas
#Es una coleccion de elementos que puede ser ordenanda, modificada, etc...
#Se identifica por los corchetes
#ejemplo:
aula = ['Huertas','Barvo','Bonifacio','Caballero']
print(aula)
# Out:
# ['Huertas', 'Barvo', 'Bonifacio', 'Caballero']

# %%
#Tambien se puede imprimir con solo menionar la Lista
aula
# Out:
# ['Huertas', 'Barvo', 'Bonifacio', 'Caballero']

# %%
#Podemos extraer cada elemento por su posicion
print(aula[0])
print(aula[1])
# Out:
# Huertas
# Barvo

# %%
#Puedo asignar un valor a una posicion de la lista
aula[1] ='Fernandez'
aula[1]
# Out:
# 'Fernandez'

# %%
#Mostramos como quedo la lista
aula
# Out:
# ['Huertas', 'Fernandez', 'Bonifacio', 'Caballero']

# %%
#para agregar un elemento utilizamos append
aula.append("Mamani")
aula.append("Bonifacio")
aula
# Out:
# ['Huertas', 'Fernandez', 'Bonifacio', 'Caballero', 'Mamani', 'Bonifacio']

# %%
#Para eliminar elemento utilizamos remove[]
aula.remove("Huertas")
aula
# Out:
# ['Fernandez', 'Bonifacio', 'Caballero', 'Mamani', 'Bonifacio']

# %%
#Si hubiera varios elementos de valore siguales se elimina la primera que coinciden
aula.remove("Bonifacio")
aula
# Out:
# ['Fernandez', 'Caballero', 'Mamani', 'Bonifacio']

# %%
#para obtener el tamaño de la lista utilizamos len()
len(aula)
# Out:
# 4

# %%
#para recorrer podemos utilizar una estructura repetitiva
for alumno in aula:
  print(alumno)
# Out:
# Fernandez
# Caballero
# Mamani
# Bonifacio

# %%
#Para invertir la lista utilizamos reverse()
#Invertir no siginifica ordenar en forma descendente sin invertir la lista
aula.reverse()
aula
# Out:
# ['Bonifacio', 'Mamani', 'Caballero', 'Fernandez']

# %%
#Para ordenar una lista utilizamos sort()
aula.sort()
aula
# Out:
# ['Bonifacio', 'Caballero', 'Fernandez', 'Mamani']

# %%
#1.2 Tuplas
#Es una coleccion de elementos ordenanda (Ordenado)

# %%
#1.3 Conjuntos
#Es una coleccion de elementos que no esta ordenado
#significa que no tiene un indice
conjunto_aula={'Huertas','Bravo','Bonifacion','Caballero'}
conjunto_aula
# Out:
# {'Bonifacion', 'Bravo', 'Caballero', 'Huertas'}

# %%
#Se puede recorrer utilizando una estructura repetitiva
#ejemplo: for
for alumno in conjunto_aula:
  print(alumno)
# Out:
# Huertas
# Bonifacion
# Caballero
# Bravo

# %%
#Observacion: No se puede acceder por posicion pues no considera indexacion
#por ejemplo:
conjunto_aula[2] devolveria un mensaje de error#examen
# Out:
#   File "<ipython-input-23-8a47529170b1>", line 3
#     conjunto_aula[2] devolveria un mensaje de error#examen
#                      ^
# SyntaxError: invalid syntax

# %%
#Para saber la cantidad de elementos utilizamos len()
len(conjunto_aula)
# Out:
# 4

# %%
#Para agregar utilizamos la funcion add()
conjunto_aula.add("Paye")
conjunto_aula
# Out:
# {'Bonifacion', 'Bravo', 'Caballero', 'Huertas', 'Paye'}

# %%
#para eliminar elementos utilizaos la funcion remove()
conjunto_aula.remove("Bravo")
conjunto_aula
# Out:
# {'Bonifacion', 'Caballero', 'Huertas', 'Paye'}

# %%
#1.4 Diccionarios
#Es una coleeccion de elementos. que estan indexados,
#no estan ordenados y se pueden modificar
#son escritos entre llavez y estan formados por  pares de elementos
#INDICE: VALOR
diccionario_aula={2:'Huertas','1':'Bravo','dos':'Bonifacion','3':'Caballero','0':'Paye'}
diccionario_aula
# Out:
# {2: 'Huertas',
#  '1': 'Bravo',
#  'dos': 'Bonifacion',
#  '3': 'Caballero',
#  '0': 'Paye'}

# %%
#Del diccionario: diccionario_aula extraer el valor cuyo indice sea cero en string
diccionario_aula['0']
# Out:
# 'Paye'

# %%
diccionario_aula[2]
# Out:
# 'Huertas'

# %%
diccionario_aula["1"]
# Out:
# 'Bravo'

# %%
diccionario_aula["dos"]
# Out:
# 'Bonifacion'

# %%
#Para añadir un par de elementos al diccionario hacemos:
diccionario_aula['20']="Velez"
diccionario_aula
# Out:
# {2: 'Huertas',
#  '1': 'Bravo',
#  'dos': 'Bonifacion',
#  '3': 'Caballero',
#  '0': 'Paye',
#  '20': 'Velez'}

# %%
#Para eliminar un valor se utiliza pop()
#Por ejemplo, eliminar el elemento de indice dos. ejemplo: Para eliminar a Huertas
diccionario_aula.pop(2)
diccionario_aula
# Out:
# {'1': 'Bravo',
#  'dos': 'Bonifacion',
#  '3': 'Caballero',
#  '0': 'Paye',
#  '20': 'Velez'}

# %%
#Tambienb se puede eliminar utilizando del()
del(diccionario_aula['dos'])
diccionario_aula
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-a0f5f1752aa3> in <cell line: 2>()
#       1 #Tambienb se puede eliminar utilizando del()
# ----> 2 del(diccionario_aula['dos'])
#       3 diccionario_aula
#
# KeyError: 'dos'

# %%
#Para obtener el indice y el valor de cada elemento utilizamos items()
for indice,valor in diccionario_aula.items():
  print(indice,valor)
# Out:
# 1 Bravo
# 3 Caballero
# 0 Paye
# 20 Velez

# %%
# 1.5. Ejercicio
# Dado una lista de [AMES, ARTEAGA , BARRIOS , BONIFACIO, BRAVO, CABALLERO , CAÑAZACA, FERNANDEZ , FLORES , GARCIA , HERRERA , HUERTA , HUERTAS, JIMENEZ , MAMANI , MANCILLA, PABLO , PAYE , PEÑA , PIZANGO, RAMOS, SANCHEZ,SEVILLANO, TINOCO, TORRES , VALDIVIESO, VELEZ , VILLANUEVA , ZUÑIGA]
# Diseñar un código que muestre si el apellido de un estudiante (Ingresado por teclado) forma parte de la lista
# tiempo: 12 minutos

alumnos = ["AMES", "ARTEAGA" , "BARRIOS" , "BONIFACIO", "BRAVO", "CABALLERO" , "CAÑAZACA", "FERNANDEZ" , "FLORES" , "GARCIA" , "HERRERA" , "HUERTA" , "HUERTAS", "JIMENEZ" , "MAMANI" , "MANCILLA", "PABLO" , "PAYE" , "PEÑA" , "PIZANGO", "RAMOS", "SANCHEZ","SEVILLANO", "TINOCO", "TORRES" , "VALDIVIESO", "VELEZ" , "VILLANUEVA" , "ZUÑIGA"]
nombre = input("Escribe el nombre del alumno")

if nombre in alumnos:
  print("El alumno ingresado si forma parte de la lista")
else:
  print("El alumno ingresado no esta dentro de la lista")
